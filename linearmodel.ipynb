# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model 
import sklearn.metrics as sm
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression


data = pd.read_csv("employees.csv")
#data = np.genfromtxt('employees.csv', delimiter=',')[:,:-1]
#data.head()
X = data['role']
y = data['location']
#X = df.iloc[:, :-1].values    #  Independent Variable
#y = df.iloc[:, -1].values     #  Dependent Variable

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=42)

X_train = np.array(X_train).reshape((len(X_train),1))
y_train = np.array(y_train).reshape((len(y_train),1))

X_test = np.array(X_test).reshape(len(X_test), 1)
y_test = np.array(y_test).reshape(len(y_test), 1)

model = linear_model.LinearRegression()
model.fit(X_train, y_train)

y_train_pred = model.predict(X_train)
print(y_train_pred)
print(y_test)

plt.figure()
plt.scatter(X_train, y_train, color='blue', label="True Value")
plt.plot(X_train, y_train_pred, color='black', linewidth=2, label="Prediction")
plt.xlabel("Role")
plt.ylabel("Location")
plt.title('Salary Prediction')
plt.legend()
plt.show()


#plt.scatter(X_train, y_train, color='red')
#plt.plot(X_train, model.predict(X_train))
#y_train_pred = model.predict(X_train)


#import pickle as pkl

##pickled_model = pkl.load(open('trained_model.pkl', 'rb'))

#result = pickled_model.score(X_test, y_test)
#print(result)           
#df_filter = data.filter(regex='_id|name|phone|salary|employeeId|managerId')
#df_filter2 = pd.get_dummies(df_filter)

#predictedSalary = linear_model.predict(df_filter2)

#data['predictions'] = predictedSalary
#data.head(10)
# Out:
# [[50827.20982946]
#  [51280.57721088]
#  [51643.27111601]
#  [51099.23025831]
#  [50736.53635318]
#  [50555.18940061]
#  [51461.92416345]
#  [52005.96502114]
#  [50736.53635318]
#  [51733.94459229]
#  [51824.61806858]
#  [50464.51592433]
#  [51461.92416345]
#  [51824.61806858]
#  [50917.88330575]
#  [51189.9037346 ]
#  [50827.20982946]
#  [51189.9037346 ]
#  [50917.88330575]
#  [51461.92416345]
#  [51552.59763973]
#  [51824.61806858]
#  [50373.84244805]
#  [50827.20982946]
#  [50736.53635318]
#  [51733.94459229]
#  [50645.8628769 ]
#  [51552.59763973]
#  [50555.18940061]
#  [51189.9037346 ]
#  [50373.84244805]
#  [50827.20982946]
#  [51371.25068716]
#  [51915.29154486]
#  [51461.92416345]
#  [51915.29154486]
#  [51824.61806858]
#  [51371.25068716]
#  [50464.51592433]
#  [50373.84244805]
#  [50736.53635318]
#  [50373.84244805]
#  [50373.84244805]
#  [51008.55678203]
#  [51552.59763973]
#  [51824.61806858]
#  [50555.18940061]
#  [51824.61806858]
#  [50464.51592433]
#  [51008.55678203]
# ...
